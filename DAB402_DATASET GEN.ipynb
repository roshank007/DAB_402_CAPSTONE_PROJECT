# %% [markdown]
# #  Capstone Project
# ## DATASET GENERATE

# %% [markdown]
# # SYSTEM info:
#
#
# ## MS WINDOWS 11
# ## PYTHON VERSION: 3.10
# ## DEEPNOTE PAID WEB SERVICE

# %% [markdown]
# ## Data scraping, also known as web scraping, is the process of importing information from a website into a spreadsheet or local file saved on your computer.
# ## It’s one of the most efficient ways to get data from the web, and in some cases to channel that data to another website.

# %% [markdown]
# ![scarping.png](attachment:scarping.png)

# %% [markdown]
# # Here I will show just basic example of how I created my dataset for my capstone project which took almost 52 hours.

# %%
# %%capture
# !pip3 install snscrape

##Just Installing snsscrape

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from datetime import datetime

# %%
data = pd.DataFrame((sntwitter.TwitterSearchScraper(
    '"#tsla since:2022-01-01 until:2021-01-07"').get_items()))

# %%
# !snscrape twitter-search "#tsla since:2022-01-01 until:2022-01-07" > tsla.txt

# %%
data = pd.DataFrame((sntwitter.TwitterSearchScraper("#tsla since:2022-01-01 until:2022-01-07").get_items()))

# %%
data
# Out:
#                                                     url  \
# 0     https://twitter.com/teslaCupertino/status/1479...
# 1     https://twitter.com/teslaCupertino/status/1479...
# 2     https://twitter.com/10trillionBTC/status/14792...
# 3     https://twitter.com/yubirunsnyc/status/1479237...
# 4     https://twitter.com/Moshkelgosha_M/status/1479...
# ...                                                 ...
# 1569  https://twitter.com/Lowcarb_Style/status/14770...
# 1570  https://twitter.com/tumtmum/status/14770759697...
# 1571  https://twitter.com/white55605421/status/14770...
# 1572  https://twitter.com/NorthernCow_Boy/status/147...
# 1573  https://twitter.com/JesseCochard/status/147706...
#
#                           date  \
# 0    2022-01-06 23:54:33+00:00
# 1    2022-01-06 23:52:07+00:00
# 2    2022-01-06 23:51:59+00:00
# 3    2022-01-06 23:44:54+00:00
# 4    2022-01-06 23:24:15+00:00
# ...                        ...
# 1569 2022-01-01 00:37:39+00:00
# ...

# %%
#!snscrape --jsonl --since '2021-01-01' twitter-search "#Covid19#Gaming until:2021-06-29"  > DATAGaming.json
##THIS IS THE CONSTRAINT I USED IT.

# %%
## Now we get the dataset we will further progress to basic knowledge of our dataset.
